# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import h5py
# Out:
# /global/software/sl-7.x86_64/modules/langs/python/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def disp(img):
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.show()
    plt.close()

# %%
f = h5py.File('/global/home/users/andy-wu/imGen/data/128normalized.h5', 'r')
data = np.array(f['images'])
disp(data[0])

# %%
# %cd ~/imGen/images
# %ls
# Out:
# /global/home/users/andy-wu/imGen/images
# wgan128_20190724153052/  wgan128_20190807151518/  wgan_20190722153845/
# wgan128_20190725153531/  wgan256_20190807155141/  wgan_20190723151222/
# wgan128_20190726114206/  wgan256_20190808173015/  wgan_20190723203004/
# wgan128_20190802154540/  wgan256_20190808182815/  wgan_20190724011058/
# wgan128_20190806152542/  wgan2_20190724221010/    wgan_20190724145328/

# %%
# %cd wgan128_20190807151518/
# %ls
# Out:
# /global/home/users/andy-wu/imGen/images/wgan128_20190807151518
# 0.png      12000.png  16000.png  2000.png   5000.png  9000.png  f3.png
# 1000.png   13000.png  17000.png  20000.png  6000.png  f0.png    f4.png
# 10000.png  14000.png  18000.png  3000.png   7000.png  f1.png
# 11000.png  15000.png  19000.png  4000.png   8000.png  f2.png

# %%
for i in range(0, 10000+1, 1000):
    disp(mpimg.imread('{}.png'.format(i)))

# %%
for i in range(5):
    disp(mpimg.imread('f{}.png'.format(i)))
